# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(2023)

year = np.linspace(start=1986, stop=2023, num=38)
      
v1 = np.random.poisson(4, len(year)) * np.linspace(start=0.1, stop=1, num=38)
v2 = np.random.poisson(6, len(year))
v3 = np.random.poisson(3.6, len(year)) / np.linspace(start=0.1, stop=1, num=38)

# %%
dataset = pd.DataFrame({'year': year, 'v1': v1, 'v2': v2, 'v3': v3})
dataset
# Out:
#       year        v1  v2         v3
# 0   1986.0  0.400000   4  80.000000
# 1   1987.0  0.124324   4  16.086957
# 2   1988.0  0.891892   7  26.909091
# 3   1989.0  0.518919   5  17.343750
# 4   1990.0  0.197297   9  20.273973
# 5   1991.0  0.664865   8  18.048780
# 6   1992.0  0.491892   9  20.329670
# 7   1993.0  1.891892   5  18.500000
# 8   1994.0  1.472973   5  13.577982
# 9   1995.0  0.956757   7   6.271186
# 10  1996.0  1.716216   3  14.566929
# 11  1997.0  1.837838   8   5.441176
# 12  1998.0  1.959459   6  10.206897
# 13  1999.0  2.913514   8   7.207792
# 14  2000.0  1.321622   4   4.539877
# 15  2001.0  0.464865   6  17.209302
# 16  2002.0  2.445946   5  10.220994
# 17  2003.0  1.027027   5  13.631579
# 18  2004.0  2.689189   7   5.577889
# 19  2005.0  3.372973   1  10.673077
# 20  2006.0  4.691892   6   5.115207
# 21  2007.0  2.443243   1   3.274336
# 22  2008.0  3.175676   8   7.872340
# 23  2009.0  1.318919   6   1.516393
# 24  2010.0  2.735135   5   1.462451
# 25  2011.0  4.248649   8   5.648855
# 26  2012.0  2.197297   8   5.461255
# 27  2013.0  3.783784  11   9.250000
# 28  2014.0  3.124324   6   5.121107
# 29  2015.0  2.416216   4   4.966443
# 30  2016.0  1.659459   7   4.820847
# 31  2017.0  8.540541   8   0.000000
# 32  2018.0  1.756757   5   6.830769
# 33  2019.0  3.610811   5   3.323353
# 34  2020.0  4.635135   8   6.472303
# 35  2021.0  5.708108  10   2.102273
# 36  2022.0  3.902703   6   7.174515
# 37  2023.0  8.000000   6   1.000000

# %%
dataset1 = pd.melt(dataset, id_vars="year", value_vars = 'v1')
dataset2 = pd.melt(dataset, id_vars="year", value_vars = 'v2')
dataset3 = pd.melt(dataset, id_vars="year", value_vars = 'v3')
df12 = dataset1.append(dataset2)
df123 = df12.append(dataset3)
df123
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_24144\2811990895.py:4: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_24144\2811990895.py:5: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#       year variable     value
# 0   1986.0       v1  0.400000
# 1   1987.0       v1  0.124324
# 2   1988.0       v1  0.891892
# 3   1989.0       v1  0.518919
# 4   1990.0       v1  0.197297
# ..     ...      ...       ...
# 33  2019.0       v3  3.323353
# 34  2020.0       v3  6.472303
# 35  2021.0       v3  2.102273
# 36  2022.0       v3  7.174515
# 37  2023.0       v3  1.000000
#
# [114 rows x 3 columns]

# %%
sns.relplot(data = df123, y='value', x='year', row = 'variable', kind='line', height=1, aspect=4)
plt.figure(figsize=(10, 10))
plt.show()
